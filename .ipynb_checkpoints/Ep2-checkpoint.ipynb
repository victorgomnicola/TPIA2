# %%
import sys
import numpy as np
from scipy.sparse import csr_matrix

# %%
def carrega_arquivo(nome_arquivo,tamanhoGrid):

    crs = open(nome_arquivo, "r")
    curenty_action = ''
    list_states = []
    dict_actions = {}
    initial_state = ''
    goal_state = ''
    
    session = [['states', 'endstates'], ['action', 'endaction'], ['cost', 'endcost'],
               ['initialstate', 'endinitialstate'], ['goalstate', 'endgoalstate']]
    curenty_session = ''

    index_to_state = {}
    cont = 1
    
    M = np.zeros(tamanhoGrid*tamanhoGrid+1)
    tamanhoGrid = tamanhoGrid + 1
    for i in range(1, tamanhoGrid):
        for j in range(1, tamanhoGrid):
            state = 'robot-at-x{a}y{b}'.format(a=j, b=i)
            index_to_state[state] = cont
            M[cont] = tamanhoGrid-j + tamanhoGrid-i - 2
            cont += 1
            

    matrix_curenty_index_state = np.array([])
    matrix_next_index_state = np.array([])
    matrix_curenty_index_action = np.array([])
    matrix_propabilities = np.array([])
    matrix_cost = np.array([])

    matrix_move_south = []
    matrix_move_north = []
    matrix_move_west = []
    matrix_move_east = []

    matrix_cost_move_south = []
    matrix_cost_move_north = []
    matrix_cost_move_west = []
    matrix_cost_move_east = []

    for columns in (raw.strip().split() for raw in crs):
        if len(columns) != 0:

            if columns[0] == 'states':
                curenty_session = session[0][0]

            elif columns[0] == session[0][1]:
                curent_action = ''

            elif columns[0] == 'action':
                curenty_session = session[1][0]
                curenty_action = columns[1]

            elif columns[0] == session[1][1]:
                if curenty_action == 'move-south':
                    matrix_move_south = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))
                    matrix_cost_move_south = csr_matrix(
                        (matrix_cost, (matrix_curenty_index_state, matrix_next_index_state)), shape=(tamanhoGrid*tamanhoGrid, tamanhoGrid*tamanhoGrid))
                    matrix_curenty_index_state = []
                    matrix_next_index_state = []
                    matrix_curenty_index_action = []
                    matrix_propabilities = []
                    matrix_cost = []

                elif curenty_action == 'move-north':
                    matrix_move_north = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))
                    matrix_cost_move_north = csr_matrix(
                        (matrix_cost, (matrix_curenty_index_state, matrix_next_index_state)),  shape=(tamanhoGrid*tamanhoGrid, tamanhoGrid*tamanhoGrid))
                    matrix_curenty_index_state = []
                    matrix_next_index_state = []
                    matrix_curenty_index_action = []
                    matrix_propabilities = []
                    matrix_cost = []

                elif curenty_action == 'move-west':
                    matrix_move_west = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))
                    matrix_cost_move_west = csr_matrix(
                        (matrix_cost, (matrix_curenty_index_state, matrix_next_index_state)),  shape=(tamanhoGrid*tamanhoGrid, tamanhoGrid*tamanhoGrid))
                    matrix_curenty_index_state = []
                    matrix_next_index_state = []
                    matrix_curenty_index_action = []
                    matrix_propabilities = []
                    matrix_cost = []

                elif curenty_action == 'move-east':
                    matrix_move_east = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))
                    matrix_cost_move_east = csr_matrix(
                        (matrix_cost, (matrix_curenty_index_state, matrix_next_index_state)),  shape=(tamanhoGrid*tamanhoGrid, tamanhoGrid*tamanhoGrid))
                    matrix_curenty_index_state = []
                    matrix_next_index_state = []
                    matrix_curenty_index_action = []
                    matrix_propabilities = []
                    matrix_cost = []

                curent_action = ''

            elif columns[0] == 'cost':
                curenty_session = session[2][0]

            elif columns[0] == session[2][1]:
                curent_action = ''

            elif columns[0] == 'initialstate':
                curenty_session = session[3][0]

            elif columns[0] == session[3][1]:
                curent_action = ''

            elif columns[0] == 'goalstate':
                curenty_session = session[4][0]

            elif columns[0] == session[4][1]:
                curent_action = ''
                break


            else:
                if len(columns) > 0:
                    if curenty_session == session[0][0]:  # states
                        list_states = []
                        for a in columns:
                            replaced_state = a.replace(',','')
                            list_states.append(index_to_state[replaced_state])

                    elif curenty_session == session[1][0]:  # action
                        
                        curenty_index_state = index_to_state[columns[0]]
                        next_index_state = index_to_state[columns[1]]
                        propabilities = columns[2]

                        matrix_curenty_index_state = np.append(matrix_curenty_index_state, int(curenty_index_state),
                                                               axis=None)
                        matrix_next_index_state = np.append(matrix_next_index_state, int(next_index_state), axis=None)
                        matrix_propabilities = np.append(matrix_propabilities, float(propabilities), axis=None)
                        matrix_cost = np.append(matrix_cost, 1, axis=None)

                    elif curenty_session == session[2][0]:  # cost
                        cost = 1

                    elif curenty_session == session[3][0]:  # initial_state
                        initial_state = index_to_state[columns[0]]

                    elif curenty_session == session[4][0]:  # goal_state
                        goal_state = index_to_state[columns[0]]
                    
    #print(matrix_move_south)
    matrix_probabilties = [matrix_move_south, matrix_move_north, matrix_move_west, matrix_move_east]
    matrix_costs = [matrix_cost_move_south, matrix_cost_move_north, matrix_cost_move_west, matrix_cost_move_east]
    
    for s in range(len(M)):
        if M[s] not in list_states:
            M[s] = sys.maxsize - 1000
    return matrix_probabilties, matrix_costs, curenty_action, list_states, dict_actions, initial_state, goal_state, M

# %%
def valueIteration(matrix_probabilties, list_states, goal_state, numStates, ehpistola, V):
    
    A = len(matrix_probabilties)
    S = numStates
   
    num_iteracoes = 0
    meta = goal_state
    V[meta] = 0
    while True:
        Q = np.zeros((A, S))
        for a in range(A):
            for s in list_states:

                if matrix_probabilties[a][s].getnnz() != 0:
                    if s != meta:
                        Q[a][s] = 1
                    for p in matrix_probabilties[a][s]:
                        data = p.data
                        indice = p.indices
                        for i in range(len(data)):
                            Q[a][s] += 0.99 * data[i] * V[indice[i]]
                    # print('a', a,'s', s,'data', data, 'indice', indice, 'Q', Q[a][s])
                else:
                    Q[a][s] = sys.maxsize - 1000

        num_iteracoes += 1
        #print(num_iteracoes)

        v_antigo = V.copy()

        for s in range(S):
            minimo = sys.maxsize
            for a in range(A):
                if Q[a][s] < minimo:
                    minimo = Q[a][s]
            V[s] = minimo
        #print(max(abs(v_antigo - V)))
        if max(abs(v_antigo - V)) < ehpistola:
            break

    return V

# %%
for i in range(tamGrid):
    for j in range(tamGrid):
        if i*20 + j in list_states:
            print(1, ' ', end = false)
        else:
            print(0, ' ', end = false)
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-fa8cb9a37f17> in <module>
#       4             print(1, ' ', end = false)
#       5         else:
# ----> 6             print(0, ' ', end = false)
#       7     print()
#
# NameError: name 'false' is not defined

# %%
nome_arquivo = "C:/Users/Avell/Documents/2019 - 02/TPIA/EP2/aaaaaaaaaa/TPIA2/TestesGrid/DeterministicGoalState/navigation_1.net"
tamGrid = 20

G, matrix_costs, curenty_action, list_states, dict_actions, initial_state, goal_state, M = carrega_arquivo(
    nome_arquivo,tamGrid)

if goal_state == None:
    raise('Arquivo com formato diferente')
    
S = tamGrid*tamGrid+1
V = np.zeros(S) + sys.maxsize - 1000
#politica = valueIteration(G, list_states, goal_state, S, 0.01, V)

# %%
grafo_otimo, politica = onde_esta_o_LAO(G, M, initial_state, goal_state, S)
# Out:
# iteracao do LAO* 1
# estado na iteracao 1 : 1
# lista de sucessores do estado  1 na iteracao 1 : [21, 2]
# lista de estados na borda na iteracao 1 : [21, 2]
# lista de estados que alcancam S: [1, 21, 2]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis []
# melhor solucao parcial [1, 21]
# ***************************************
# iteracao do LAO* 2
# estado na iteracao 2 : 21
# lista de sucessores do estado  21 na iteracao 2 : [41, 22]
# lista de estados na borda na iteracao 2 : [2, 41, 22]
# lista de estados que alcancam S: [21, 41, 1, 22, 2]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  41
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 41]
# ***************************************
# iteracao do LAO* 3
# estado na iteracao 3 : 41
# lista de sucessores do estado  41 na iteracao 3 : [61, 42]
# lista de estados na borda na iteracao 3 : [2, 22, 61, 42]
# lista de estados que alcancam S: [41, 61, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [41]
# o melhor estado foi:  41
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 41]
# estados alcancaveis [61]
# o melhor estado foi:  61
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 41, 61]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 41, 61]
# ***************************************
# iteracao do LAO* 4
# estado na iteracao 4 : 61
# lista de sucessores do estado  61 na iteracao 4 : [81, 62]
# lista de estados na borda na iteracao 4 : [2, 22, 42, 81, 62]
# lista de estados que alcancam S: [61, 81, 41, 62, 42, 22, 2, 21, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [61]
# o melhor estado foi:  61
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 61]
# estados alcancaveis [41, 81]
# o melhor estado foi:  81
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 61, 81]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 61, 81]
# ***************************************
# iteracao do LAO* 5
# estado na iteracao 5 : 81
# lista de sucessores do estado  81 na iteracao 5 : [101, 82]
# lista de estados na borda na iteracao 5 : [2, 22, 42, 62, 101, 82]
# lista de estados que alcancam S: [81, 101, 61, 82, 62, 42, 22, 41, 21, 1, 2]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [81]
# o melhor estado foi:  81
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 81]
# estados alcancaveis [61, 101]
# o melhor estado foi:  101
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 81, 101]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 81, 101]
# ***************************************
# iteracao do LAO* 6
# estado na iteracao 6 : 101
# lista de sucessores do estado  101 na iteracao 6 : [121, 102]
# lista de estados na borda na iteracao 6 : [2, 22, 42, 62, 82, 121, 102]
# lista de estados que alcancam S: [101, 121, 81, 102, 82, 62, 42, 61, 41, 21, 1, 22, 2]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [101]
# o melhor estado foi:  101
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 101]
# estados alcancaveis [81, 121]
# o melhor estado foi:  121
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 101, 121]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 101, 121]
# ***************************************
# iteracao do LAO* 7
# estado na iteracao 7 : 121
# lista de sucessores do estado  121 na iteracao 7 : [141, 122]
# lista de estados na borda na iteracao 7 : [2, 22, 42, 62, 82, 102, 141, 122]
# lista de estados que alcancam S: [121, 141, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [121]
# o melhor estado foi:  121
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 121]
# estados alcancaveis [101, 141]
# o melhor estado foi:  141
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 121, 141]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 121, 141]
# ***************************************
# iteracao do LAO* 8
# estado na iteracao 8 : 141
# lista de sucessores do estado  141 na iteracao 8 : [161, 142]
# lista de estados na borda na iteracao 8 : [2, 22, 42, 62, 82, 102, 122, 161, 142]
# lista de estados que alcancam S: [141, 161, 121, 142, 122, 102, 82, 101, 81, 61, 41, 62, 42, 22, 2, 21, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [141]
# o melhor estado foi:  141
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 141]
# estados alcancaveis [121, 161]
# o melhor estado foi:  161
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 141, 161]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 141, 161]
# ***************************************
# iteracao do LAO* 9
# estado na iteracao 9 : 161
# lista de sucessores do estado  161 na iteracao 9 : [162]
# lista de estados na borda na iteracao 9 : [2, 22, 42, 62, 82, 102, 122, 142, 162]
# lista de estados que alcancam S: [161, 141, 162, 142, 122, 102, 121, 101, 81, 61, 82, 62, 42, 22, 41, 21, 1, 2]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [161]
# o melhor estado foi:  161
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161]
# estados alcancaveis [141]
# o melhor estado foi:  141
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161, 141]
# estados alcancaveis [121]
# o melhor estado foi:  121
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161, 141, 121]
# estados alcancaveis [101]
# o melhor estado foi:  101
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161, 141, 121, 101]
# estados alcancaveis [81]
# o melhor estado foi:  81
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161, 141, 121, 101, 81]
# estados alcancaveis [61]
# o melhor estado foi:  61
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161, 141, 121, 101, 81, 61]
# estados alcancaveis [41]
# o melhor estado foi:  41
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161, 141, 121, 101, 81, 61, 41]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 161, 141, 121, 101, 81, 61, 41]
# ***************************************
# iteracao do LAO* 10
# estado na iteracao 10 : 162
# lista de sucessores do estado  162 na iteracao 10 : [182, 163]
# lista de estados na borda na iteracao 10 : [2, 22, 42, 62, 82, 102, 122, 142, 182, 163]
# lista de estados que alcancam S: [162, 182, 142, 163, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  182
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 182]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 182]
# ***************************************
# iteracao do LAO* 11
# estado na iteracao 11 : 182
# lista de sucessores do estado  182 na iteracao 11 : [202, 183]
# lista de estados na borda na iteracao 11 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 202, 183]
# lista de estados que alcancam S: [182, 202, 162, 183, 163, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [182]
# o melhor estado foi:  182
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 182]
# estados alcancaveis [202]
# o melhor estado foi:  202
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 182, 202]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 182, 202]
# ***************************************
# iteracao do LAO* 12
# estado na iteracao 12 : 202
# lista de sucessores do estado  202 na iteracao 12 : [222, 201, 203]
# lista de estados na borda na iteracao 12 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 222, 201, 203]
# lista de estados que alcancam S: [202, 222, 182, 203, 201, 183, 163, 162, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [203, 182]
# o melhor estado foi:  203
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203]
# estados alcancaveis [202]
# o melhor estado foi:  202
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 202]
# estados alcancaveis [182, 222, 201]
# o melhor estado foi:  222
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 202, 222]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 202, 222]
# ***************************************
# iteracao do LAO* 13
# estado na iteracao 13 : 222
# lista de sucessores do estado  222 na iteracao 13 : [242, 221, 223]
# lista de estados na borda na iteracao 13 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 242, 221, 223]
# lista de estados que alcancam S: [222, 242, 202, 223, 221, 201, 203, 183, 163, 182, 162, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [203, 182]
# o melhor estado foi:  203
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203]
# estados alcancaveis [223, 202]
# o melhor estado foi:  223
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223]
# estados alcancaveis [222]
# o melhor estado foi:  222
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222]
# estados alcancaveis [202, 242, 221]
# o melhor estado foi:  242
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 242]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 242]
# ***************************************
# iteracao do LAO* 14
# estado na iteracao 14 : 242
# lista de sucessores do estado  242 na iteracao 14 : [262, 241]
# lista de estados na borda na iteracao 14 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 223, 262, 241]
# lista de estados que alcancam S: [242, 262, 222, 241, 221, 201, 202, 182, 203, 223, 183, 163, 162, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [203, 182]
# o melhor estado foi:  203
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203]
# estados alcancaveis [223, 202]
# o melhor estado foi:  223
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223]
# estados alcancaveis [222]
# o melhor estado foi:  222
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222]
# estados alcancaveis [202, 242, 221]
# o melhor estado foi:  242
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 242]
# estados alcancaveis [262, 241]
# o melhor estado foi:  262
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 242, 262]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 242, 262]
# ***************************************
# iteracao do LAO* 15
# estado na iteracao 15 : 262
# lista de sucessores do estado  262 na iteracao 15 : [282, 261, 263]
# lista de estados na borda na iteracao 15 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 223, 241, 282, 261, 263]
# lista de estados que alcancam S: [262, 282, 242, 263, 261, 241, 221, 201, 222, 202, 223, 203, 183, 163, 182, 162, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [203, 182]
# o melhor estado foi:  203
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203]
# estados alcancaveis [223, 202]
# o melhor estado foi:  223
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223]
# estados alcancaveis [222]
# o melhor estado foi:  222
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222]
# estados alcancaveis [202, 242, 221]
# o melhor estado foi:  202
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 202]
# estados alcancaveis [182, 201]
# o melhor estado foi:  182
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 202, 182]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 222, 202, 182]
# ***************************************
# iteracao do LAO* 16
# estado na iteracao 16 : 223
# lista de sucessores do estado  223 na iteracao 16 : [224]
# lista de estados na borda na iteracao 16 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 224]
# lista de estados que alcancam S: [223, 203, 224, 222, 242, 202, 221, 241, 201, 261, 262, 282, 263, 182, 162, 183, 163, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [203, 182]
# o melhor estado foi:  203
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203]
# estados alcancaveis [223, 202]
# o melhor estado foi:  223
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223]
# estados alcancaveis [222, 224]
# o melhor estado foi:  224
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 224]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 223, 224]
# ***************************************
# iteracao do LAO* 17
# estado na iteracao 17 : 224
# lista de sucessores do estado  224 na iteracao 17 : [204, 244, 225]
# lista de estados na borda na iteracao 17 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 204, 244, 225]
# lista de estados que alcancam S: [224, 244, 204, 225, 223, 203, 222, 242, 202, 221, 241, 201, 261, 262, 282, 263, 182, 162, 183, 163, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [203, 182]
# o melhor estado foi:  203
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203]
# estados alcancaveis [223, 202, 204]
# o melhor estado foi:  204
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 204]
# estados alcancaveis [224]
# o melhor estado foi:  224
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 204, 224]
# estados alcancaveis [244, 223, 225]
# o melhor estado foi:  244
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 204, 224, 244]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 203, 204, 224, 244]
# ***************************************
# iteracao do LAO* 18
# estado na iteracao 18 : 204
# lista de sucessores do estado  204 na iteracao 18 : [184, 205]
# lista de estados na borda na iteracao 18 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 244, 225, 184, 205]
# lista de estados que alcancam S: [204, 224, 184, 205, 203, 223, 183, 202, 222, 182, 201, 221, 241, 261, 242, 262, 282, 263, 162, 142, 163, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1, 225, 244]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183]
# o melhor estado foi:  183
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183]
# estados alcancaveis [203, 182, 184]
# o melhor estado foi:  184
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 184]
# estados alcancaveis [204]
# o melhor estado foi:  204
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 184, 204]
# estados alcancaveis [224, 203, 205]
# o melhor estado foi:  205
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 184, 204, 205]
# estados alcancaveis [225]
# o melhor estado foi:  225
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 184, 204, 205, 225]
# estados alcancaveis [224]
# o melhor estado foi:  224
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 184, 204, 205, 225, 224]
# estados alcancaveis [244, 223]
# o melhor estado foi:  244
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 184, 204, 205, 225, 224, 244]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 183, 184, 204, 205, 225, 224, 244]
# ***************************************
# iteracao do LAO* 19
# estado na iteracao 19 : 184
# lista de sucessores do estado  184 na iteracao 19 : [164, 185]
# lista de estados na borda na iteracao 19 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 244, 225, 205, 164, 185]
# lista de estados que alcancam S: [184, 204, 164, 185, 183, 203, 163, 182, 202, 162, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1, 222, 201, 221, 241, 261, 242, 262, 282, 263, 223, 224, 244, 225, 205]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183, 164]
# o melhor estado foi:  164
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164]
# estados alcancaveis [184]
# o melhor estado foi:  184
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 184]
# estados alcancaveis [204, 183, 185]
# o melhor estado foi:  185
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 184, 185]
# estados alcancaveis [205]
# o melhor estado foi:  205
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 184, 185, 205]
# estados alcancaveis [225, 204]
# o melhor estado foi:  225
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 184, 185, 205, 225]
# estados alcancaveis [224]
# o melhor estado foi:  224
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 184, 185, 205, 225, 224]
# estados alcancaveis [204, 244, 223]
# o melhor estado foi:  244
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 184, 185, 205, 225, 224, 244]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 184, 185, 205, 225, 224, 244]
# ***************************************
# iteracao do LAO* 20
# estado na iteracao 20 : 164
# lista de sucessores do estado  164 na iteracao 20 : [144, 165]
# lista de estados na borda na iteracao 20 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 244, 225, 205, 185, 144, 165]
# lista de estados que alcancam S: [164, 184, 144, 165, 163, 183, 162, 182, 142, 161, 141, 121, 101, 122, 102, 82, 62, 81, 61, 41, 21, 42, 22, 2, 1, 202, 222, 203, 201, 221, 241, 261, 242, 262, 282, 263, 223, 204, 224, 205, 225, 185, 244]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162]
# estados alcancaveis [182, 161, 163]
# o melhor estado foi:  163
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163]
# estados alcancaveis [183, 164]
# o melhor estado foi:  164
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164]
# estados alcancaveis [144, 184, 165]
# o melhor estado foi:  144
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 144]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 162, 163, 164, 144]
# ***************************************
# iteracao do LAO* 21
# estado na iteracao 21 : 144
# lista de sucessores do estado  144 na iteracao 21 : [124, 143]
# lista de estados na borda na iteracao 21 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 244, 225, 205, 185, 165, 124, 143]
# lista de estados que alcancam S: [144, 164, 124, 143, 163, 142, 162, 122, 141, 161, 121, 101, 81, 102, 82, 62, 42, 61, 41, 21, 1, 22, 2, 182, 202, 183, 203, 184, 204, 185, 205, 165, 225, 224, 244, 223, 222, 242, 221, 241, 201, 261, 262, 282, 263]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121]
# o melhor estado foi:  142
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142]
# estados alcancaveis [162, 141, 143]
# o melhor estado foi:  143
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 143]
# estados alcancaveis [163, 144]
# o melhor estado foi:  144
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 143, 144]
# estados alcancaveis [124, 164]
# o melhor estado foi:  124
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 142, 143, 144, 124]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 142, 143, 144, 124]
# ***************************************
# iteracao do LAO* 22
# estado na iteracao 22 : 124
# lista de sucessores do estado  124 na iteracao 22 : [104, 123, 125]
# lista de estados na borda na iteracao 22 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 244, 225, 205, 185, 165, 143, 104, 123, 125]
# lista de estados que alcancam S: [124, 144, 104, 125, 123, 143, 122, 142, 102, 121, 141, 101, 81, 61, 82, 62, 42, 22, 41, 21, 1, 2, 161, 162, 182, 163, 183, 164, 184, 165, 185, 205, 225, 204, 224, 203, 223, 202, 222, 201, 221, 241, 261, 242, 262, 282, 263, 244]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101]
# o melhor estado foi:  122
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102, 122]
# estados alcancaveis [142, 121, 123]
# o melhor estado foi:  123
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 123]
# estados alcancaveis [143, 124]
# o melhor estado foi:  124
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 123, 124]
# estados alcancaveis [104, 144, 125]
# o melhor estado foi:  104
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 122, 123, 124, 104]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 122, 123, 124, 104]
# ***************************************
# iteracao do LAO* 23
# estado na iteracao 23 : 104
# lista de sucessores do estado  104 na iteracao 23 : [84, 103, 105]
# lista de estados na borda na iteracao 23 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 244, 225, 205, 185, 165, 143, 123, 125, 84, 103, 105]
# lista de estados que alcancam S: [104, 124, 84, 105, 103, 123, 102, 122, 82, 101, 121, 81, 61, 41, 62, 42, 22, 2, 21, 1, 141, 161, 142, 162, 143, 163, 144, 164, 184, 165, 185, 205, 225, 204, 224, 203, 223, 183, 202, 222, 182, 201, 221, 241, 261, 242, 262, 282, 263, 244, 125]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  22
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22]
# estados alcancaveis [2, 42]
# o melhor estado foi:  42
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42]
# estados alcancaveis [62, 41]
# o melhor estado foi:  62
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62]
# estados alcancaveis [82, 61]
# o melhor estado foi:  82
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82]
# estados alcancaveis [102, 81]
# o melhor estado foi:  102
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 22, 42, 62, 82, 102]
# estados alcancaveis [122, 101, 103]
# o melhor estado foi:  103
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 103]
# estados alcancaveis [123, 104]
# o melhor estado foi:  104
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 22, 42, 62, 82, 102, 103, 104]
# estados alcancaveis [84, 124, 105]
# o melhor estado foi:  84
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 22, 42, 62, 82, 102, 103, 104, 84]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 22, 42, 62, 82, 102, 103, 104, 84]
# ***************************************
# iteracao do LAO* 24
# estado na iteracao 24 : 84
# lista de sucessores do estado  84 na iteracao 24 : [64, 83, 85]
# lista de estados na borda na iteracao 24 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 282, 261, 263, 244, 225, 205, 185, 165, 143, 123, 125, 103, 105, 64, 83, 85]
# lista de estados que alcancam S: [84, 104, 64, 85, 83, 103, 82, 102, 62, 81, 101, 61, 41, 21, 42, 22, 2, 1, 121, 141, 122, 142, 123, 143, 124, 144, 125, 105, 164, 184, 165, 163, 183, 162, 182, 161, 202, 222, 203, 201, 221, 241, 261, 242, 262, 282, 263, 223, 204, 224, 205, 225, 185, 244]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# ...
# o melhor estado foi:  297
# A acao que levou ao melhor estado foi:  2
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 324, 325, 326, 327, 328, 348, 368, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 318, 298, 297]
# estados alcancaveis [277, 317, 296]
# o melhor estado foi:  317
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 324, 325, 326, 327, 328, 348, 368, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 318, 298, 297, 317]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 324, 325, 326, 327, 328, 348, 368, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 318, 298, 297, 317]
# ***************************************
# iteracao do LAO* 201
# estado na iteracao 201 : 338
# lista de sucessores do estado  338 na iteracao 201 : [358]
# lista de estados na borda na iteracao 201 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 261, 263, 225, 205, 185, 165, 143, 123, 125, 103, 105, 83, 85, 65, 5, 47, 88, 106, 108, 126, 128, 146, 148, 166, 168, 186, 188, 206, 226, 246, 248, 266, 286, 288, 326, 346, 348, 368, 365, 384, 390, 370, 304, 343, 342, 281, 302, 8, 70, 111, 129, 149, 151, 169, 189, 71, 52, 32, 35, 53, 55, 73, 112, 93, 303, 172, 114, 209, 289, 270, 323, 96, 135, 116, 229, 173, 175, 193, 195, 215, 233, 235, 253, 255, 294, 273, 275, 118, 136, 156, 176, 178, 198, 216, 218, 238, 256, 258, 276, 298, 318, 335, 309, 252, 291, 293, 311, 313, 331, 351, 353, 391, 394, 192, 39, 100, 40, 160, 219, 259, 279, 299, 319, 339, 359, 379, 60, 80, 232, 310, 350, 120, 140, 315, 355, 396, 375, 377, 334, 374, 358]
# lista de estados que alcancam S: [338, 358, 318, 339, 337, 317, 336, 356, 335, 355, 315, 334, 333, 353, 313, 332, 352, 312, 331, 351, 311, 330, 350, 310, 329, 309, 328, 348, 308, 327, 347, 307, 326, 346, 325, 345, 305, 324, 344, 304, 323, 343, 303, 283, 302, 282, 301, 321, 281, 261, 241, 262, 242, 263, 264, 244, 265, 285, 266, 286, 246, 267, 287, 247, 268, 288, 248, 269, 289, 270, 250, 271, 291, 251, 272, 292, 252, 273, 293, 253, 274, 294, 254, 275, 295, 255, 276, 296, 256, 277, 297, 257, 237, 258, 238, 259, 279, 260, 280, 240, 220, 200, 219, 218, 198, 217, 197, 216, 215, 235, 195, 214, 234, 194, 174, 193, 173, 192, 212, 172, 191, 211, 190, 210, 170, 189, 209, 169, 188, 208, 168, 187, 207, 167, 186, 206, 166, 185, 205, 165, 184, 204, 164, 183, 203, 163, 182, 202, 162, 142, 161, 141, 121, 101, 122, 102, 123, 143, 103, 124, 144, 104, 125, 105, 126, 146, 106, 127, 147, 107, 128, 148, 108, 129, 149, 130, 150, 110, 131, 151, 111, 132, 152, 112, 133, 113, 134, 154, 114, 135, 115, 136, 156, 116, 137, 157, 117, 138, 158, 118, 139, 159, 119, 140, 160, 120, 100, 80, 99, 79, 98, 78, 97, 77, 96, 76, 95, 94, 74, 93, 73, 92, 91, 71, 90, 70, 89, 69, 88, 87, 67, 47, 66, 46, 65, 85, 45, 64, 84, 63, 83, 43, 62, 82, 42, 61, 81, 41, 21, 1, 22, 2, 23, 24, 4, 25, 5, 26, 27, 7, 28, 48, 8, 29, 49, 30, 50, 10, 11, 12, 32, 13, 14, 34, 15, 35, 16, 36, 17, 18, 38, 19, 39, 20, 40, 60, 59, 58, 57, 56, 55, 54, 53, 52, 51, 180, 179, 178, 177, 176, 175, 222, 201, 221, 223, 224, 225, 226, 227, 228, 229, 230, 232, 233, 300, 320, 299, 319, 298, 340, 360, 380, 359, 379, 341, 361, 342, 381, 382, 383, 363, 384, 364, 385, 365, 386, 387, 367, 388, 368, 389, 369, 390, 370, 391, 392, 372, 393, 373, 394, 374, 375, 376, 396, 377]
# fim da iteracao de valor
# reconstruindo Gv
# Gv: [1]
# estados alcancaveis [21, 2]
# o melhor estado foi:  21
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21]
# estados alcancaveis [41, 22]
# o melhor estado foi:  41
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41]
# estados alcancaveis [61, 42]
# o melhor estado foi:  61
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61]
# estados alcancaveis [81, 62]
# o melhor estado foi:  81
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81]
# estados alcancaveis [101, 82]
# o melhor estado foi:  101
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101]
# estados alcancaveis [121, 102]
# o melhor estado foi:  121
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121]
# estados alcancaveis [141, 122]
# o melhor estado foi:  141
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141]
# estados alcancaveis [161, 142]
# o melhor estado foi:  161
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161]
# estados alcancaveis [162]
# o melhor estado foi:  162
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162]
# estados alcancaveis [142, 182, 163]
# o melhor estado foi:  182
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182]
# estados alcancaveis [202, 183]
# o melhor estado foi:  202
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202]
# estados alcancaveis [222, 201, 203]
# o melhor estado foi:  222
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222]
# estados alcancaveis [242, 221, 223]
# o melhor estado foi:  242
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242]
# estados alcancaveis [262, 241]
# o melhor estado foi:  262
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262]
# estados alcancaveis [282, 261, 263]
# o melhor estado foi:  282
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282]
# estados alcancaveis [302, 281, 283]
# o melhor estado foi:  302
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302]
# estados alcancaveis [301, 303]
# o melhor estado foi:  303
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303]
# estados alcancaveis [283, 323, 304]
# o melhor estado foi:  323
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323]
# estados alcancaveis [343, 324]
# o melhor estado foi:  343
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343]
# estados alcancaveis [363, 342, 344]
# o melhor estado foi:  363
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363]
# estados alcancaveis [383, 364]
# o melhor estado foi:  383
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383]
# estados alcancaveis [382, 384]
# o melhor estado foi:  384
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384]
# estados alcancaveis [364, 385]
# o melhor estado foi:  385
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385]
# estados alcancaveis [365, 386]
# o melhor estado foi:  386
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386]
# estados alcancaveis [387]
# o melhor estado foi:  387
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387]
# estados alcancaveis [367, 388]
# o melhor estado foi:  388
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388]
# estados alcancaveis [368, 389]
# o melhor estado foi:  389
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389]
# estados alcancaveis [369, 390]
# o melhor estado foi:  390
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390]
# estados alcancaveis [370, 391]
# o melhor estado foi:  391
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391]
# estados alcancaveis [392]
# o melhor estado foi:  392
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392]
# estados alcancaveis [372, 393]
# o melhor estado foi:  393
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393]
# estados alcancaveis [373, 394]
# o melhor estado foi:  394
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394]
# estados alcancaveis [374]
# o melhor estado foi:  374
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374]
# estados alcancaveis [373, 375]
# o melhor estado foi:  375
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375]
# estados alcancaveis [355, 376]
# o melhor estado foi:  355
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355]
# estados alcancaveis [335, 356]
# o melhor estado foi:  335
# A acao que levou ao melhor estado foi:  0
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335]
# estados alcancaveis [315, 334, 336]
# o melhor estado foi:  336
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336]
# estados alcancaveis [356, 337]
# o melhor estado foi:  337
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337]
# estados alcancaveis [317, 338]
# o melhor estado foi:  338
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338]
# estados alcancaveis [318, 358, 339]
# o melhor estado foi:  358
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 358]
# estados alcancaveis [359]
# o melhor estado foi:  359
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 358, 359]
# estados alcancaveis [339, 379, 360]
# o melhor estado foi:  379
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 358, 359, 379]
# estados alcancaveis [380]
# o melhor estado foi:  380
# A acao que levou ao melhor estado foi:  3
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 358, 359, 379, 380]
# estados alcancaveis [360, 400]
# o melhor estado foi:  400
# A acao que levou ao melhor estado foi:  1
# Gv: [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 358, 359, 379, 380, 400]
# estados alcancaveis []
# melhor solucao parcial [1, 21, 41, 61, 81, 101, 121, 141, 161, 162, 182, 202, 222, 242, 262, 282, 302, 303, 323, 343, 363, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 374, 375, 355, 335, 336, 337, 338, 358, 359, 379, 380, 400]
# ***************************************
# iteracao do LAO* 202
# estado na iteracao 202 : 394
# lista de sucessores do estado  394 na iteracao 202 : [395]
# lista de estados na borda na iteracao 202 : [2, 22, 42, 62, 82, 102, 122, 142, 163, 183, 201, 203, 221, 241, 261, 263, 225, 205, 185, 165, 143, 123, 125, 103, 105, 83, 85, 65, 5, 47, 88, 106, 108, 126, 128, 146, 148, 166, 168, 186, 188, 206, 226, 246, 248, 266, 286, 288, 326, 346, 348, 368, 365, 384, 390, 370, 304, 343, 342, 281, 302, 8, 70, 111, 129, 149, 151, 169, 189, 71, 52, 32, 35, 53, 55, 73, 112, 93, 303, 172, 114, 209, 289, 270, 323, 96, 135, 116, 229, 173, 175, 193, 195, 215, 233, 235, 253, 255, 294, 273, 275, 118, 136, 156, 176, 178, 198, 216, 218, 238, 256, 258, 276, 298, 318, 335, 309, 252, 291, 293, 311, 313, 331, 351, 353, 391, 192, 39, 100, 40, 160, 219, 259, 279, 299, 319, 339, 359, 379, 60, 80, 232, 310, 350, 120, 140, 315, 355, 396, 375, 377, 334, 374, 358, 395]
# lista de estados que alcancam S: [394, 374, 395, 393, 373, 392, 372, 391, 390, 370, 389, 369, 388, 368, 387, 367, 386, 385, 365, 384, 364, 383, 363, 382, 381, 361, 341, 321, 342, 343, 323, 344, 324, 345, 325, 346, 326, 347, 327, 348, 328, 308, 329, 309, 330, 350, 310, 331, 351, 311, 332, 352, 312, 333, 353, 313, 334, 335, 355, 315, 336, 356, 337, 317, 338, 358, 318, 339, 359, 319, 340, 360, 320, 300, 280, 299, 279, 298, 297, 277, 296, 276, 295, 275, 294, 274, 293, 273, 292, 272, 291, 271, 251, 270, 250, 269, 289, 268, 288, 248, 267, 287, 247, 266, 286, 246, 265, 285, 264, 244, 263, 283, 262, 282, 242, 261, 281, 241, 221, 201, 222, 202, 223, 203, 224, 204, 225, 205, 226, 206, 227, 207, 228, 208, 229, 209, 230, 210, 190, 211, 191, 212, 232, 192, 172, 193, 173, 194, 214, 174, 195, 215, 175, 176, 156, 177, 197, 157, 178, 198, 158, 179, 159, 180, 200, 160, 140, 120, 139, 119, 138, 118, 137, 117, 136, 116, 135, 115, 134, 154, 114, 133, 113, 132, 152, 112, 131, 151, 111, 130, 150, 110, 129, 149, 128, 148, 108, 127, 147, 107, 126, 146, 106, 125, 105, 124, 144, 104, 123, 143, 103, 122, 142, 102, 121, 141, 101, 81, 61, 82, 62, 83, 63, 84, 64, 85, 65, 45, 66, 46, 67, 87, 47, 27, 48, 28, 49, 69, 29, 50, 70, 30, 51, 71, 52, 32, 53, 73, 54, 74, 34, 55, 35, 56, 76, 36, 57, 77, 58, 78, 38, 59, 79, 39, 60, 80, 40, 20, 19, 18, 17, 16, 15, 14, 13, 12, 11, 10, 100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88, 8, 7, 26, 25, 5, 24, 4, 23, 43, 22, 42, 2, 21, 41, 1, 161, 162, 182, 163, 183, 164, 184, 165, 185, 166, 186, 167, 187, 168, 188, 169, 189, 170, 220, 240, 219, 218, 238, 217, 237, 216, 257, 258, 256, 255, 235, 254, 234, 253, 233, 252, 259, 260, 301, 302, 303, 304, 305, 307, 380, 379, 376, 396, 377, 375]

# %%
print(len(grafo_otimo))


for tupla in politica:
    print(tupla)
# Out:
# 39
# (1, 0)
# (21, 0)
# (41, 0)
# (61, 0)
# (81, 0)
# (101, 0)
# (121, 0)
# (141, 0)
# (161, 0)
# (162, 0)
# (182, 0)
# (202, 0)
# (222, 0)
# (242, 0)
# (262, 0)
# (282, 0)
# (302, 0)
# (303, 0)
# (323, 0)
# (324, 0)
# (325, 0)
# (326, 0)
# (327, 0)
# (328, 0)
# (329, 0)
# (330, 0)
# (350, 0)
# (351, 0)
# (352, 0)
# (372, 0)
# (373, 0)
# (374, 0)
# (375, 0)
# (376, 0)
# (377, 0)
# (378, 0)
# (379, 0)
# (380, 0)
# (400, 0)

# %%
def retorna_politica(G, grafo_otimo, v_lao):
    politica = []
    
    for estado in grafo_otimo:
        estados_alcancaveis = []
        acao_estado = []
        for a in range(4):
            if G[a][estado].getnnz() != 0:
                for p in G[a][estado]:
                    indice = p.indices
                    for i in range(len(indice)):
                        if indice[i] not in estados_alcancaveis:
                            estados_alcancaveis.append(indice[i])
                            acao_estado.append(a)
                        
        print('estados_alcancaveis', estados_alcancaveis)
        print('acao_estado', acao_estado)
        print('valores', V[estados_alcancaveis])
        acao_melhor_estado = acao_estado[np.argmin(V[estados_alcancaveis])]
        
        politica.append((estado, acao_melhor_estado))

    return politica

# %%
def onde_esta_o_LAO(G, M, initial_state, goal_state, numStates):
    V = M.copy()
    F = [initial_state]
    I = []
    G1 = [initial_state]
    Gv = [initial_state]
    
    cont = 0
    while True:
        
        cont += 1
        print('iteracao do LAO*', cont)
        
        s = melhorS(F, Gv, V)
        if not s:
            break
        
        
        print('estado na iteracao', cont, ':', s)
        lista_sucessores = expandPartialSolution(G, G1, s, V, goal_state)
        print('lista de sucessores do estado ', s , 'na iteracao', cont, ':', lista_sucessores)
        
        
        
        F.remove(s)
        
        for sucessor in lista_sucessores:
            if sucessor not in F:
                F.append(sucessor)
                
        I.append(s)
        print('lista de estados na borda na iteracao', cont, ':', F)
        
        Z = achievableStates(G, G1, s)
        print('lista de estados que alcancam S:', Z)
        
        V = valueIteration(G, Z, goal_state, numStates, 0.01, V)
        print('fim da iteracao de valor')
        Gv = rebuildGv(G, G1, V, initial_state)
        print('melhor solucao parcial', Gv)
        print('***************************************')
        
    politica = retorna_politica(G, Gv, V)
    return politica

# %%
def rebuildGv(G, G1, V, initial_state):
    Gv_novo = [initial_state]
    melhor_estado = initial_state
    print('reconstruindo Gv')
    while True:
        print('Gv:', Gv_novo)
        estados_alcancaveis = []
        acao_estado = []
        for a in range(4):
            if G[a][melhor_estado].getnnz() != 0:
                for p in G[a][melhor_estado]:
                    indice = p.indices
                    for i in range(len(indice)):
                        if indice[i] in G1 and indice[i] not in estados_alcancaveis and indice[i] not in Gv_novo:
                            estados_alcancaveis.append(indice[i])
                            acao_estado.append(a)
        print('estados alcancaveis', estados_alcancaveis)
        if len(estados_alcancaveis) == 0:
            break
            
        estado_atual = melhor_estado
        melhor_estado = estados_alcancaveis[np.argmin(V[estados_alcancaveis])]
        acao_melhor_estado = acao_estado[np.argmin(V[estados_alcancaveis])]
        print('o melhor estado foi: ', melhor_estado)
        print('A acao que levou ao melhor estado foi: ', acao_melhor_estado)
        
        for p in G[acao_melhor_estado][estado_atual]:
            indice = p.indices
            for i in range(len(indice)):
                if indice[i] not in Gv_novo:
                    Gv_novo.append(indice[i])
    return Gv_novo

# %%
def melhorS(F, Gv, V):
    Fv = []
    for estado in F:
        if estado in Gv:
            Fv.append(estado)
    if len(Fv): return Fv[np.argmin(V[Fv])]
    else: return None

# %%
#essa funcao encontra os sucessores de n e adiciona-os a G1
#e retorna a lista de sucessores
def expandPartialSolution(G, G1, s, V, goal_state):
    lista_sucessores = []
    A = 4
    
    for a in range(A):
        if G[a][s].getnnz() != 0:
            for p in G[a][s]:
                indice = p.indices
                for i in range(len(indice)):
                    if indice[i] not in lista_sucessores and indice[i] not in G1:
                        lista_sucessores.append(indice[i])
                        G1.append(indice[i])

    return lista_sucessores

# %%
GT = [matrix_probabilities[x].transpose(copy=True) for x in range(4)]

# %%
def achievableStates(G,G1,s):
    GT = [G[x].transpose(copy=True) for x in range(4)]
    result = []
    
    result.append(s)
    
    resultCopy = result.copy()
    
    while len(resultCopy)!=0 :
        
        sLinha = resultCopy.pop()
        
        for aa in range(4):
            for states in GT[aa].getrow(sLinha):
                for state in states.indices:
                    if state not in result and state in G1:
                        result.append(state)
                        resultCopy.append(state)
                    
    return result

# %%
achievableStates(matrix_probabilities,[x for x in range(20)],7)

# %%
gv = [1]
a = 0
print(len(gv))
for i in gv:
    gv.append(0)
    if len(gv) == 10:
        break
    print(len(gv))

# %%
#main

matrix_propabilities = []
matrix_curenty_index_state = []
matrix_next_index_state = []
tamanhoGrid = 21
matrix_move_south = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))
matrix_move_north = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))
matrix_move_west = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))
matrix_move_east = csr_matrix(
                        (matrix_propabilities, (matrix_curenty_index_state, matrix_next_index_state)),
                        shape=(tamanhoGrid * tamanhoGrid, tamanhoGrid * tamanhoGrid))

g1 = [matrix_move_south, matrix_move_north, matrix_move_west, matrix_move_east]
n = 1
lista_sucessores = expandPartialSolution(matrix_probabilities, g1, n)
melhorN(lista_sucessores, M, n)
